# %%
from tf.app import use
A = use('q-ran/quran', hoist=globals())
# Out:
# <b title="local commit">TF-app:</b> <span title="#def1fc1f23fbbb9ca6265dd0c3c3d594aa3f3f8c offline under ~/text-fabric-data">~/text-fabric-data/q-ran/quran/app</span>
# <b title="local release">data:</b> <span title="rv0.5=#60bd6788dadb13974e89df55cde7687c0593e65f offline under ~/text-fabric-data">~/text-fabric-data/q-ran/quran/tf/0.4</span>
# This is Text-Fabric 9.4.1
# Api reference : https://annotation.github.io/text-fabric/tf/cheatsheet.html
#
# 40 features found and 0 ignored
# ...

# %%
for lemma in sorted(list({F.lemma.v(w) for w in F.otype.s('word') if F.lemma.v(w)})):
    print(lemma)
# Out:
# $a>on
# $aAEir
# $aA^'a
# $aA^q~u
# $aAhid
# $aAkilat
# $aAkir
# $aAni}
# $aAriko
# $aAwiro
# $aEa`^}ir
# $aTaT
# $aTo_#
# $aTor
# $aYo'
# $a`Ti}
# $a`fiEiyn
# $a`mixa`t
# $a`xiSap
# $adado
# $adiyd
# $afaA
# $afa`Eap
# $afatayon
# $afiyE
# $agafa
# $agalato
# $aha`da`t
# $aha`dap
# $ahida
# $ahiyd
# $ahiyq
# $ahor
# $ahowap
# $ajar
# $ajara
# $ajarap
# $akara
# $akol
# $akuwr
# $ak~
# $amaA^}il
# $amos
# $ana_#aAn
# $aqaqo
# $aqiy~
# $aqu
# $aq~
# $ara
# $araAb
# $araEa
# $araHa
# $arar
# $ariba
# $ariyEap
# $ariyk
# $aroqiy~
# $aroqiy~ap
# $ar~
# $ar~ido
# $at~aY`
# $awob
# $ayoTa`n
# $ayob
# $ayobap
# $ayox
# $ifaA^'
# $ihaAb
# $iqaAq
# $iqowat
# $iq~
# $iro*imap
# $iroEap
# $irob
# $irok
# $iyEap
# $iyap
# $iyb
# $uEab
# $uEayob
# $uEuwb
# $uHuwm
# $uH~
# $ub~iha
# $ugul
# $uhub
# $ukor
# $ukuwr
# $urob
# $ur~aE
# $uwaAZ
# $uwraY`
# $~a`ribiyn
# $~afaq
# $~afoE
# $~ahawa`t
# $~awaY`
# $~awokap
# $~iEor
# $~iEoraY`
# $~imaAl
# $~itaA^'
# $~uq~ap
# 'aA*an
# 'aAfiliyn
# 'aAkiluwn
# ...
